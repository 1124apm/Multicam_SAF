# %% [markdown]
# # 파이썬과 MySQL 연동하기

# %%
# pip install pymysql

# %%
import pymysql
import os

# %%
# 1. DB 연결 설정
conn = pymysql.connect(
    host= os.getenv('team_ip'),             # 팀 DB와 연결
    user='sbunpa',                          # MySQL 사용자명
    password= os.getenv('team_password'),   # 본인이 설정한 비밀번호
    db='S-Bun-Pa',                          # 만든 데이터베이스 이름
    charset='utf8mb4'
)

# 2. 커서(Cursor) 생성: SQL 명령어를 실행해주는 일꾼
cursor = conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[4], line 2
#       1 # 1. DB 연결 설정
# ----> 2 conn = pymysql.connect(
#       3     host= os.getenv('team_ip'),             # 팀 DB와 연결
#       4     user='sbunpa',                          # MySQL 사용자명
#       5     password= os.getenv('team_password'),   # 본인이 설정한 비밀번호
#       6     db='S-Bun-Pa',                          # 만든 데이터베이스 이름
#       7     charset='utf8mb4'
#       8 )
#      10 # 2. 커서(Cursor) 생성: SQL 명령어를 실행해주는 일꾼
#      11 cursor = conn.cursor()
#
# ...

# %%
# 3. 데이터 삽입
sql = """
INSERT INTO Crawl_db (team_id, team_name, league, soruce_url, raw_text, collected_at) 
VALUES (%s, %s, %s, %s, %s, %s)
"""

# 넣을 데이터 (예시)
# data = (1, '맨체스터 시티', 'Premier League', 'http://...', '팀 설명 어쩌구...', '2025-12-23')

try:
    cursor.execute(sql, data)
    conn.commit() # 중요! 이걸 해야 실제로 DB에 저장이 돼.
    print("데이터 삽입 성공!")
except Exception as e:
    conn.rollback() # 에러 나면 되돌리기
    print(f"에러 발생: {e}")
finally:
    conn.close() # 작업 끝나면 연결 끊어주기
